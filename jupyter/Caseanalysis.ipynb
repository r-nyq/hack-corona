# %%
#For further details, tutorials and documentations, 
#  please consult our Github account:  https://github.com/tsi-dih 
#Please note that, if you want to know the data files list of this project, 
#  you can go to DIH Portal->Control Center->Storage, 
#  and then go to hackcorona_33@dih.telekom.net/1298/521 directory 
#if you leave parameter path as empty or '<FILENAME>', we will return the first available data file 
from dih.storage import read_storage_account

data = read_storage_account(
    path = '<FILENAME>',
    project_id = '521',
    workspace_id = '1298',
    application_key = '9df6429c-0083-4dc4-bed3-7f0edde2b5f2',
    api_gateway_endpoint = 'https://api.dih.telekom.net/api/v1/storage/fs/readfile',
    account = "pdataanalyticshub",
    username = "hackcorona_33@dih.telekom.net"
)

print(len(data))

# %%
data

# %%
import requests
import json

# %%
url = "https://opendata.arcgis.com/datasets/dd4580c810204019a7b8eb3e0b329dd6_0.geojson"

# %%
urlData = requests.get(url).content

# %%
jsonContent = json.loads(urlData.decode('utf-8'))

# %%
jsonContent
# Out:
# {'type': 'FeatureCollection',
#  'features': [{'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'SK Magdeburg',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154936,
#     'Meldedatum': '2020-03-18T00:00:00.000Z',
#     'IdLandkreis': '15003'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'SK Magdeburg',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154937,
#     'Meldedatum': '2020-03-12T00:00:00.000Z',
#     'IdLandkreis': '15003'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'SK Magdeburg',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154938,
#     'Meldedatum': '2020-03-17T00:00:00.000Z',
#     'IdLandkreis': '15003'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'SK Magdeburg',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154939,
#     'Meldedatum': '2020-03-10T00:00:00.000Z',
#     'IdLandkreis': '15003'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'SK Magdeburg',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154940,
#     'Meldedatum': '2020-03-19T00:00:00.000Z',
#     'IdLandkreis': '15003'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'SK Magdeburg',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154941,
#     'Meldedatum': '2020-03-18T00:00:00.000Z',
#     'IdLandkreis': '15003'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'SK Magdeburg',
#     'Altersgruppe': 'A80+',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154942,
#     'Meldedatum': '2020-03-17T00:00:00.000Z',
#     'IdLandkreis': '15003'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'SK Magdeburg',
#     'Altersgruppe': 'A80+',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154943,
#     'Meldedatum': '2020-03-13T00:00:00.000Z',
#     'IdLandkreis': '15003'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'SK Magdeburg',
#     'Altersgruppe': 'A80+',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154944,
#     'Meldedatum': '2020-03-18T00:00:00.000Z',
#     'IdLandkreis': '15003'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Altmarkkreis Salzwedel',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154945,
#     'Meldedatum': '2020-03-12T00:00:00.000Z',
#     'IdLandkreis': '15081'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Altmarkkreis Salzwedel',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154946,
#     'Meldedatum': '2020-03-16T00:00:00.000Z',
#     'IdLandkreis': '15081'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Anhalt-Bitterfeld',
#     'Altersgruppe': 'A05-A14',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154947,
#     'Meldedatum': '2020-03-16T00:00:00.000Z',
#     'IdLandkreis': '15082'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Anhalt-Bitterfeld',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154948,
#     'Meldedatum': '2020-03-11T00:00:00.000Z',
#     'IdLandkreis': '15082'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Anhalt-Bitterfeld',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154949,
#     'Meldedatum': '2020-03-12T00:00:00.000Z',
#     'IdLandkreis': '15082'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Anhalt-Bitterfeld',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154950,
#     'Meldedatum': '2020-03-19T00:00:00.000Z',
#     'IdLandkreis': '15082'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Anhalt-Bitterfeld',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154951,
#     'Meldedatum': '2020-03-16T00:00:00.000Z',
#     'IdLandkreis': '15082'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Anhalt-Bitterfeld',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154952,
#     'Meldedatum': '2020-03-16T00:00:00.000Z',
#     'IdLandkreis': '15082'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Anhalt-Bitterfeld',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154953,
#     'Meldedatum': '2020-03-19T00:00:00.000Z',
#     'IdLandkreis': '15082'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Börde',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154954,
#     'Meldedatum': '2020-03-16T00:00:00.000Z',
#     'IdLandkreis': '15083'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Börde',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154955,
#     'Meldedatum': '2020-03-18T00:00:00.000Z',
#     'IdLandkreis': '15083'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Börde',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154956,
#     'Meldedatum': '2020-03-16T00:00:00.000Z',
#     'IdLandkreis': '15083'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Börde',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154957,
#     'Meldedatum': '2020-03-18T00:00:00.000Z',
#     'IdLandkreis': '15083'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Börde',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154958,
#     'Meldedatum': '2020-03-11T00:00:00.000Z',
#     'IdLandkreis': '15083'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Börde',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 5,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154959,
#     'Meldedatum': '2020-03-16T00:00:00.000Z',
#     'IdLandkreis': '15083'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Börde',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154960,
#     'Meldedatum': '2020-03-17T00:00:00.000Z',
#     'IdLandkreis': '15083'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Börde',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154961,
#     'Meldedatum': '2020-03-16T00:00:00.000Z',
#     'IdLandkreis': '15083'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Börde',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154962,
#     'Meldedatum': '2020-03-17T00:00:00.000Z',
#     'IdLandkreis': '15083'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Börde',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154963,
#     'Meldedatum': '2020-03-18T00:00:00.000Z',
#     'IdLandkreis': '15083'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Börde',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154964,
#     'Meldedatum': '2020-03-19T00:00:00.000Z',
#     'IdLandkreis': '15083'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Börde',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154965,
#     'Meldedatum': '2020-03-12T00:00:00.000Z',
#     'IdLandkreis': '15083'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Börde',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'W',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154966,
#     'Meldedatum': '2020-03-19T00:00:00.000Z',
#     'IdLandkreis': '15083'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Börde',
#     'Altersgruppe': 'A80+',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154967,
#     'Meldedatum': '2020-03-17T00:00:00.000Z',
#     'IdLandkreis': '15083'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Burgenlandkreis',
#     'Altersgruppe': 'A05-A14',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154968,
#     'Meldedatum': '2020-03-18T00:00:00.000Z',
#     'IdLandkreis': '15084'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Burgenlandkreis',
#     'Altersgruppe': 'A05-A14',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154969,
#     'Meldedatum': '2020-03-19T00:00:00.000Z',
#     'IdLandkreis': '15084'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Burgenlandkreis',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154970,
#     'Meldedatum': '2020-03-16T00:00:00.000Z',
#     'IdLandkreis': '15084'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Burgenlandkreis',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154971,
#     'Meldedatum': '2020-03-17T00:00:00.000Z',
#     'IdLandkreis': '15084'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Burgenlandkreis',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154972,
#     'Meldedatum': '2020-03-13T00:00:00.000Z',
#     'IdLandkreis': '15084'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Burgenlandkreis',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154973,
#     'Meldedatum': '2020-03-16T00:00:00.000Z',
#     'IdLandkreis': '15084'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Burgenlandkreis',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154974,
#     'Meldedatum': '2020-03-18T00:00:00.000Z',
#     'IdLandkreis': '15084'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Burgenlandkreis',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154975,
#     'Meldedatum': '2020-03-16T00:00:00.000Z',
#     'IdLandkreis': '15084'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Burgenlandkreis',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154976,
#     'Meldedatum': '2020-03-18T00:00:00.000Z',
#     'IdLandkreis': '15084'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Burgenlandkreis',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154977,
#     'Meldedatum': '2020-03-16T00:00:00.000Z',
#     'IdLandkreis': '15084'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Burgenlandkreis',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154978,
#     'Meldedatum': '2020-03-18T00:00:00.000Z',
#     'IdLandkreis': '15084'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Burgenlandkreis',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154979,
#     'Meldedatum': '2020-03-19T00:00:00.000Z',
#     'IdLandkreis': '15084'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Burgenlandkreis',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154980,
#     'Meldedatum': '2020-03-10T00:00:00.000Z',
#     'IdLandkreis': '15084'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Harz',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154981,
#     'Meldedatum': '2020-03-17T00:00:00.000Z',
#     'IdLandkreis': '15085'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Harz',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154982,
#     'Meldedatum': '2020-03-19T00:00:00.000Z',
#     'IdLandkreis': '15085'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Harz',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154983,
#     'Meldedatum': '2020-03-12T00:00:00.000Z',
#     'IdLandkreis': '15085'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Harz',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154984,
#     'Meldedatum': '2020-03-17T00:00:00.000Z',
#     'IdLandkreis': '15085'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Harz',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154985,
#     'Meldedatum': '2020-03-19T00:00:00.000Z',
#     'IdLandkreis': '15085'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Harz',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154986,
#     'Meldedatum': '2020-03-12T00:00:00.000Z',
#     'IdLandkreis': '15085'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Harz',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154987,
#     'Meldedatum': '2020-03-17T00:00:00.000Z',
#     'IdLandkreis': '15085'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Harz',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154988,
#     'Meldedatum': '2020-03-19T00:00:00.000Z',
#     'IdLandkreis': '15085'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Harz',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154989,
#     'Meldedatum': '2020-03-19T00:00:00.000Z',
#     'IdLandkreis': '15085'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Harz',
#     'Altersgruppe': 'unbekannt',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154990,
#     'Meldedatum': '2020-03-17T00:00:00.000Z',
#     'IdLandkreis': '15085'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Jerichower Land',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154991,
#     'Meldedatum': '2020-03-18T00:00:00.000Z',
#     'IdLandkreis': '15086'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Jerichower Land',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154992,
#     'Meldedatum': '2020-03-18T00:00:00.000Z',
#     'IdLandkreis': '15086'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Jerichower Land',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154993,
#     'Meldedatum': '2020-03-13T00:00:00.000Z',
#     'IdLandkreis': '15086'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Mansfeld-Südharz',
#     'Altersgruppe': 'A05-A14',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154994,
#     'Meldedatum': '2020-03-19T00:00:00.000Z',
#     'IdLandkreis': '15087'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Mansfeld-Südharz',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154995,
#     'Meldedatum': '2020-03-19T00:00:00.000Z',
#     'IdLandkreis': '15087'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Mansfeld-Südharz',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154996,
#     'Meldedatum': '2020-03-11T00:00:00.000Z',
#     'IdLandkreis': '15087'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Mansfeld-Südharz',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154997,
#     'Meldedatum': '2020-03-17T00:00:00.000Z',
#     'IdLandkreis': '15087'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Mansfeld-Südharz',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154998,
#     'Meldedatum': '2020-03-17T00:00:00.000Z',
#     'IdLandkreis': '15087'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Saalekreis',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 154999,
#     'Meldedatum': '2020-03-17T00:00:00.000Z',
#     'IdLandkreis': '15088'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Saalekreis',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155000,
#     'Meldedatum': '2020-03-18T00:00:00.000Z',
#     'IdLandkreis': '15088'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Saalekreis',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155001,
#     'Meldedatum': '2020-03-19T00:00:00.000Z',
#     'IdLandkreis': '15088'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Saalekreis',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155002,
#     'Meldedatum': '2020-03-16T00:00:00.000Z',
#     'IdLandkreis': '15088'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Saalekreis',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155003,
#     'Meldedatum': '2020-03-16T00:00:00.000Z',
#     'IdLandkreis': '15088'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Saalekreis',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155004,
#     'Meldedatum': '2020-03-18T00:00:00.000Z',
#     'IdLandkreis': '15088'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Saalekreis',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 3,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155005,
#     'Meldedatum': '2020-03-19T00:00:00.000Z',
#     'IdLandkreis': '15088'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Saalekreis',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155006,
#     'Meldedatum': '2020-03-19T00:00:00.000Z',
#     'IdLandkreis': '15088'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Saalekreis',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155007,
#     'Meldedatum': '2020-03-10T00:00:00.000Z',
#     'IdLandkreis': '15088'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Salzlandkreis',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155008,
#     'Meldedatum': '2020-03-19T00:00:00.000Z',
#     'IdLandkreis': '15089'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Salzlandkreis',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155009,
#     'Meldedatum': '2020-03-10T00:00:00.000Z',
#     'IdLandkreis': '15089'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Salzlandkreis',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155010,
#     'Meldedatum': '2020-03-12T00:00:00.000Z',
#     'IdLandkreis': '15089'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Salzlandkreis',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155011,
#     'Meldedatum': '2020-03-13T00:00:00.000Z',
#     'IdLandkreis': '15089'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Salzlandkreis',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155012,
#     'Meldedatum': '2020-03-19T00:00:00.000Z',
#     'IdLandkreis': '15089'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Salzlandkreis',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155013,
#     'Meldedatum': '2020-03-11T00:00:00.000Z',
#     'IdLandkreis': '15089'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Salzlandkreis',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155014,
#     'Meldedatum': '2020-03-19T00:00:00.000Z',
#     'IdLandkreis': '15089'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Salzlandkreis',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155015,
#     'Meldedatum': '2020-03-11T00:00:00.000Z',
#     'IdLandkreis': '15089'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Salzlandkreis',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'W',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155016,
#     'Meldedatum': '2020-03-11T00:00:00.000Z',
#     'IdLandkreis': '15089'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Salzlandkreis',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155017,
#     'Meldedatum': '2020-03-19T00:00:00.000Z',
#     'IdLandkreis': '15089'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Stendal',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155018,
#     'Meldedatum': '2020-03-16T00:00:00.000Z',
#     'IdLandkreis': '15090'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Stendal',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155019,
#     'Meldedatum': '2020-03-17T00:00:00.000Z',
#     'IdLandkreis': '15090'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Stendal',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155020,
#     'Meldedatum': '2020-03-17T00:00:00.000Z',
#     'IdLandkreis': '15090'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Stendal',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155021,
#     'Meldedatum': '2020-03-19T00:00:00.000Z',
#     'IdLandkreis': '15090'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Stendal',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155022,
#     'Meldedatum': '2020-03-17T00:00:00.000Z',
#     'IdLandkreis': '15090'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Stendal',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155023,
#     'Meldedatum': '2020-03-19T00:00:00.000Z',
#     'IdLandkreis': '15090'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Wittenberg',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155024,
#     'Meldedatum': '2020-03-12T00:00:00.000Z',
#     'IdLandkreis': '15091'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Wittenberg',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155025,
#     'Meldedatum': '2020-03-17T00:00:00.000Z',
#     'IdLandkreis': '15091'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Wittenberg',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 3,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155026,
#     'Meldedatum': '2020-03-19T00:00:00.000Z',
#     'IdLandkreis': '15091'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Wittenberg',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155027,
#     'Meldedatum': '2020-03-12T00:00:00.000Z',
#     'IdLandkreis': '15091'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Wittenberg',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155028,
#     'Meldedatum': '2020-03-19T00:00:00.000Z',
#     'IdLandkreis': '15091'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 15,
#     'Bundesland': 'Sachsen-Anhalt',
#     'Landkreis': 'LK Wittenberg',
#     'Altersgruppe': 'unbekannt',
#     'Geschlecht': 'unbekannt',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155029,
#     'Meldedatum': '2020-03-19T00:00:00.000Z',
#     'IdLandkreis': '15091'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Erfurt',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155030,
#     'Meldedatum': '2020-03-13T00:00:00.000Z',
#     'IdLandkreis': '16051'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Erfurt',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 3,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155031,
#     'Meldedatum': '2020-03-16T00:00:00.000Z',
#     'IdLandkreis': '16051'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Erfurt',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155032,
#     'Meldedatum': '2020-03-19T00:00:00.000Z',
#     'IdLandkreis': '16051'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Erfurt',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155033,
#     'Meldedatum': '2020-03-20T00:00:00.000Z',
#     'IdLandkreis': '16051'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Erfurt',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155034,
#     'Meldedatum': '2020-03-10T00:00:00.000Z',
#     'IdLandkreis': '16051'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Erfurt',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155035,
#     'Meldedatum': '2020-03-13T00:00:00.000Z',
#     'IdLandkreis': '16051'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Erfurt',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 5,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155036,
#     'Meldedatum': '2020-03-14T00:00:00.000Z',
#     'IdLandkreis': '16051'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Erfurt',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155037,
#     'Meldedatum': '2020-03-18T00:00:00.000Z',
#     'IdLandkreis': '16051'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Erfurt',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 3,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155038,
#     'Meldedatum': '2020-03-19T00:00:00.000Z',
#     'IdLandkreis': '16051'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Erfurt',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155039,
#     'Meldedatum': '2020-03-20T00:00:00.000Z',
#     'IdLandkreis': '16051'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Erfurt',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155040,
#     'Meldedatum': '2020-03-16T00:00:00.000Z',
#     'IdLandkreis': '16051'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Erfurt',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 5,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155041,
#     'Meldedatum': '2020-03-19T00:00:00.000Z',
#     'IdLandkreis': '16051'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Erfurt',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155042,
#     'Meldedatum': '2020-03-16T00:00:00.000Z',
#     'IdLandkreis': '16051'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Erfurt',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155043,
#     'Meldedatum': '2020-03-07T00:00:00.000Z',
#     'IdLandkreis': '16051'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Erfurt',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155044,
#     'Meldedatum': '2020-03-16T00:00:00.000Z',
#     'IdLandkreis': '16051'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Gera',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155045,
#     'Meldedatum': '2020-03-18T00:00:00.000Z',
#     'IdLandkreis': '16052'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Gera',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155046,
#     'Meldedatum': '2020-03-17T00:00:00.000Z',
#     'IdLandkreis': '16052'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Gera',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155047,
#     'Meldedatum': '2020-03-11T00:00:00.000Z',
#     'IdLandkreis': '16052'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Gera',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155048,
#     'Meldedatum': '2020-03-18T00:00:00.000Z',
#     'IdLandkreis': '16052'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Jena',
#     'Altersgruppe': 'A05-A14',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155049,
#     'Meldedatum': '2020-03-17T00:00:00.000Z',
#     'IdLandkreis': '16053'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Jena',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155050,
#     'Meldedatum': '2020-03-14T00:00:00.000Z',
#     'IdLandkreis': '16053'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Jena',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155051,
#     'Meldedatum': '2020-03-17T00:00:00.000Z',
#     'IdLandkreis': '16053'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Jena',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 4,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155052,
#     'Meldedatum': '2020-03-14T00:00:00.000Z',
#     'IdLandkreis': '16053'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Jena',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155053,
#     'Meldedatum': '2020-03-17T00:00:00.000Z',
#     'IdLandkreis': '16053'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Jena',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155054,
#     'Meldedatum': '2020-03-14T00:00:00.000Z',
#     'IdLandkreis': '16053'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Jena',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155055,
#     'Meldedatum': '2020-03-17T00:00:00.000Z',
#     'IdLandkreis': '16053'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Suhl',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155056,
#     'Meldedatum': '2020-03-13T00:00:00.000Z',
#     'IdLandkreis': '16054'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Suhl',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155057,
#     'Meldedatum': '2020-03-20T00:00:00.000Z',
#     'IdLandkreis': '16054'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Weimar',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155058,
#     'Meldedatum': '2020-03-17T00:00:00.000Z',
#     'IdLandkreis': '16055'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Weimar',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155059,
#     'Meldedatum': '2020-03-20T00:00:00.000Z',
#     'IdLandkreis': '16055'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Weimar',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155060,
#     'Meldedatum': '2020-03-18T00:00:00.000Z',
#     'IdLandkreis': '16055'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Weimar',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155061,
#     'Meldedatum': '2020-03-20T00:00:00.000Z',
#     'IdLandkreis': '16055'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Weimar',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155062,
#     'Meldedatum': '2020-03-16T00:00:00.000Z',
#     'IdLandkreis': '16055'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Weimar',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155063,
#     'Meldedatum': '2020-03-17T00:00:00.000Z',
#     'IdLandkreis': '16055'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Weimar',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155064,
#     'Meldedatum': '2020-03-20T00:00:00.000Z',
#     'IdLandkreis': '16055'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Weimar',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155065,
#     'Meldedatum': '2020-03-10T00:00:00.000Z',
#     'IdLandkreis': '16055'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'SK Eisenach',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155066,
#     'Meldedatum': '2020-03-10T00:00:00.000Z',
#     'IdLandkreis': '16056'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'LK Eichsfeld',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155067,
#     'Meldedatum': '2020-03-20T00:00:00.000Z',
#     'IdLandkreis': '16061'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'LK Eichsfeld',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155068,
#     'Meldedatum': '2020-03-13T00:00:00.000Z',
#     'IdLandkreis': '16061'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'LK Eichsfeld',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155069,
#     'Meldedatum': '2020-03-20T00:00:00.000Z',
#     'IdLandkreis': '16061'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'LK Eichsfeld',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155070,
#     'Meldedatum': '2020-03-14T00:00:00.000Z',
#     'IdLandkreis': '16061'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'LK Eichsfeld',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155071,
#     'Meldedatum': '2020-03-19T00:00:00.000Z',
#     'IdLandkreis': '16061'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
#     'Bundesland': 'Thüringen',
#     'Landkreis': 'LK Eichsfeld',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 155072,
#     'Meldedatum': '2020-03-20T00:00:00.000Z',
#     'IdLandkreis': '16061'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 16,
# ...
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'W',
#     'AnzahlFall': 9,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148659,
#     'Meldedatum': '2020-03-12T00:00:00.000Z',
#     'IdLandkreis': '05370'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Heinsberg',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'W',
#     'AnzahlFall': 9,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148660,
#     'Meldedatum': '2020-03-13T00:00:00.000Z',
#     'IdLandkreis': '05370'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Heinsberg',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'W',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148661,
#     'Meldedatum': '2020-03-14T00:00:00.000Z',
#     'IdLandkreis': '05370'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Heinsberg',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'W',
#     'AnzahlFall': 3,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148662,
#     'Meldedatum': '2020-03-15T00:00:00.000Z',
#     'IdLandkreis': '05370'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Heinsberg',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'W',
#     'AnzahlFall': 12,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148663,
#     'Meldedatum': '2020-03-16T00:00:00.000Z',
#     'IdLandkreis': '05370'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Heinsberg',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'W',
#     'AnzahlFall': 10,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148664,
#     'Meldedatum': '2020-03-17T00:00:00.000Z',
#     'IdLandkreis': '05370'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Heinsberg',
#     'Altersgruppe': 'A60-A79',
#     'Geschlecht': 'W',
#     'AnzahlFall': 3,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148665,
#     'Meldedatum': '2020-03-18T00:00:00.000Z',
#     'IdLandkreis': '05370'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Heinsberg',
#     'Altersgruppe': 'A80+',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148666,
#     'Meldedatum': '2020-03-08T00:00:00.000Z',
#     'IdLandkreis': '05370'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Heinsberg',
#     'Altersgruppe': 'A80+',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148667,
#     'Meldedatum': '2020-03-09T00:00:00.000Z',
#     'IdLandkreis': '05370'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Heinsberg',
#     'Altersgruppe': 'A80+',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148668,
#     'Meldedatum': '2020-03-10T00:00:00.000Z',
#     'IdLandkreis': '05370'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Heinsberg',
#     'Altersgruppe': 'A80+',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148669,
#     'Meldedatum': '2020-03-12T00:00:00.000Z',
#     'IdLandkreis': '05370'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Heinsberg',
#     'Altersgruppe': 'A80+',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148670,
#     'Meldedatum': '2020-03-13T00:00:00.000Z',
#     'IdLandkreis': '05370'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Heinsberg',
#     'Altersgruppe': 'A80+',
#     'Geschlecht': 'M',
#     'AnzahlFall': 3,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148671,
#     'Meldedatum': '2020-03-15T00:00:00.000Z',
#     'IdLandkreis': '05370'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Heinsberg',
#     'Altersgruppe': 'A80+',
#     'Geschlecht': 'M',
#     'AnzahlFall': 6,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148672,
#     'Meldedatum': '2020-03-16T00:00:00.000Z',
#     'IdLandkreis': '05370'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Heinsberg',
#     'Altersgruppe': 'A80+',
#     'Geschlecht': 'M',
#     'AnzahlFall': 4,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148673,
#     'Meldedatum': '2020-03-17T00:00:00.000Z',
#     'IdLandkreis': '05370'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Heinsberg',
#     'Altersgruppe': 'A80+',
#     'Geschlecht': 'M',
#     'AnzahlFall': 5,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148674,
#     'Meldedatum': '2020-03-18T00:00:00.000Z',
#     'IdLandkreis': '05370'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Heinsberg',
#     'Altersgruppe': 'A80+',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148675,
#     'Meldedatum': '2020-03-08T00:00:00.000Z',
#     'IdLandkreis': '05370'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Heinsberg',
#     'Altersgruppe': 'A80+',
#     'Geschlecht': 'W',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148676,
#     'Meldedatum': '2020-03-10T00:00:00.000Z',
#     'IdLandkreis': '05370'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Heinsberg',
#     'Altersgruppe': 'A80+',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148677,
#     'Meldedatum': '2020-03-11T00:00:00.000Z',
#     'IdLandkreis': '05370'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Heinsberg',
#     'Altersgruppe': 'A80+',
#     'Geschlecht': 'W',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148678,
#     'Meldedatum': '2020-03-12T00:00:00.000Z',
#     'IdLandkreis': '05370'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Heinsberg',
#     'Altersgruppe': 'A80+',
#     'Geschlecht': 'W',
#     'AnzahlFall': 5,
#     'AnzahlTodesfall': 2,
#     'ObjectId': 148679,
#     'Meldedatum': '2020-03-13T00:00:00.000Z',
#     'IdLandkreis': '05370'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Heinsberg',
#     'Altersgruppe': 'A80+',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148680,
#     'Meldedatum': '2020-03-14T00:00:00.000Z',
#     'IdLandkreis': '05370'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Heinsberg',
#     'Altersgruppe': 'A80+',
#     'Geschlecht': 'W',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148681,
#     'Meldedatum': '2020-03-15T00:00:00.000Z',
#     'IdLandkreis': '05370'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Heinsberg',
#     'Altersgruppe': 'A80+',
#     'Geschlecht': 'W',
#     'AnzahlFall': 8,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148682,
#     'Meldedatum': '2020-03-16T00:00:00.000Z',
#     'IdLandkreis': '05370'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Heinsberg',
#     'Altersgruppe': 'A80+',
#     'Geschlecht': 'W',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148683,
#     'Meldedatum': '2020-03-17T00:00:00.000Z',
#     'IdLandkreis': '05370'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Heinsberg',
#     'Altersgruppe': 'A80+',
#     'Geschlecht': 'W',
#     'AnzahlFall': 3,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148684,
#     'Meldedatum': '2020-03-18T00:00:00.000Z',
#     'IdLandkreis': '05370'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Heinsberg',
#     'Altersgruppe': 'unbekannt',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148685,
#     'Meldedatum': '2020-03-14T00:00:00.000Z',
#     'IdLandkreis': '05370'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Heinsberg',
#     'Altersgruppe': 'unbekannt',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148686,
#     'Meldedatum': '2020-03-18T00:00:00.000Z',
#     'IdLandkreis': '05370'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Heinsberg',
#     'Altersgruppe': 'unbekannt',
#     'Geschlecht': 'unbekannt',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148687,
#     'Meldedatum': '2020-03-15T00:00:00.000Z',
#     'IdLandkreis': '05370'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Heinsberg',
#     'Altersgruppe': 'unbekannt',
#     'Geschlecht': 'unbekannt',
#     'AnzahlFall': 3,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148688,
#     'Meldedatum': '2020-03-17T00:00:00.000Z',
#     'IdLandkreis': '05370'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Oberbergischer Kreis',
#     'Altersgruppe': 'A05-A14',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148689,
#     'Meldedatum': '2020-03-18T00:00:00.000Z',
#     'IdLandkreis': '05374'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Oberbergischer Kreis',
#     'Altersgruppe': 'A05-A14',
#     'Geschlecht': 'W',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148690,
#     'Meldedatum': '2020-03-16T00:00:00.000Z',
#     'IdLandkreis': '05374'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Oberbergischer Kreis',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148691,
#     'Meldedatum': '2020-03-03T00:00:00.000Z',
#     'IdLandkreis': '05374'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Oberbergischer Kreis',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148692,
#     'Meldedatum': '2020-03-10T00:00:00.000Z',
#     'IdLandkreis': '05374'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Oberbergischer Kreis',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148693,
#     'Meldedatum': '2020-03-16T00:00:00.000Z',
#     'IdLandkreis': '05374'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Oberbergischer Kreis',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148694,
#     'Meldedatum': '2020-03-18T00:00:00.000Z',
#     'IdLandkreis': '05374'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Oberbergischer Kreis',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148695,
#     'Meldedatum': '2020-03-11T00:00:00.000Z',
#     'IdLandkreis': '05374'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Oberbergischer Kreis',
#     'Altersgruppe': 'A15-A34',
#     'Geschlecht': 'W',
#     'AnzahlFall': 3,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148696,
#     'Meldedatum': '2020-03-18T00:00:00.000Z',
#     'IdLandkreis': '05374'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Oberbergischer Kreis',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 1,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148697,
#     'Meldedatum': '2020-03-05T00:00:00.000Z',
#     'IdLandkreis': '05374'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Oberbergischer Kreis',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 4,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148698,
#     'Meldedatum': '2020-03-11T00:00:00.000Z',
#     'IdLandkreis': '05374'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Oberbergischer Kreis',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 2,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148699,
#     'Meldedatum': '2020-03-12T00:00:00.000Z',
#     'IdLandkreis': '05374'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Oberbergischer Kreis',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 9,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148700,
#     'Meldedatum': '2020-03-16T00:00:00.000Z',
#     'IdLandkreis': '05374'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Oberbergischer Kreis',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'M',
#     'AnzahlFall': 5,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148701,
#     'Meldedatum': '2020-03-18T00:00:00.000Z',
#     'IdLandkreis': '05374'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Oberbergischer Kreis',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 4,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148702,
#     'Meldedatum': '2020-03-16T00:00:00.000Z',
#     'IdLandkreis': '05374'},
#    'geometry': None},
#   {'type': 'Feature',
#    'properties': {'IdBundesland': 5,
#     'Bundesland': 'Nordrhein-Westfalen',
#     'Landkreis': 'LK Oberbergischer Kreis',
#     'Altersgruppe': 'A35-A59',
#     'Geschlecht': 'W',
#     'AnzahlFall': 5,
#     'AnzahlTodesfall': 0,
#     'ObjectId': 148703,
#     'Meldedatum': '2020-03-18T00:00:00.000Z',
#     'IdLandkreis': '05374'},
#    'geometry': None},
#   ...]}
